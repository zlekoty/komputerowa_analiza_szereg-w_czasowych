# %%
import pandas as pd
import numpy as np
import scipy as sp
import random
import scipy.stats
import math
import statistics
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"szczescie_pkb.csv")
df = df.dropna()
df = df.reset_index()

# %%
happiness = df["happines_score"]
gdp = df["gdp_per_capita"]

# %% [markdown]
# # Analiza jednowymiarowa zmiennej zależnej oraz zmiennej niezależnej

# %% [markdown]
# ## wizualizacja danych

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
ax1.hist(happiness, bins = 15, facecolor = '#2ab0ff', edgecolor='#169acf', linewidth=0.5)
ax1.set_xlabel("poziom szczęścia")
ax1.set_ylabel("ilość wystąpień")
ax1.set_title("Poziom szczęścia w wybranych państwach na świecie")

ax2.hist(gdp, bins = 14, facecolor = '#2ab0ff', edgecolor='#169acf', linewidth=0.5)
ax2.set_xlabel("PKB na osobę")
ax2.set_ylabel("ilość wystąpień")
ax2.set_title("Poziom PKB na osobę w wybranych państwach na świecie")

plt.savefig('hist.pdf', format='pdf')

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

ax1.boxplot(happiness)
ax1.set_ylabel("poziom szczęścia")

ax2.boxplot(gdp)
ax2.set_ylabel("PKB na osobę")

plt.savefig('box.pdf', format='pdf')

# %%
happiness_x = np.sort(happiness)
happiness_y = np.arange(len(happiness_x))/float(len(happiness_x))
gdp_x = np.sort(gdp)
gdp_y = np.arange(len(gdp_x))/float(len(gdp_x))

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

ax1.plot(happiness_x, happiness_y)
ax1.set_xlabel("poziom szczęścia")
ax1.set_ylabel("prawdopodobieństwo")
ax1.set_title("Poziom szczęścia w wybranych państwach na świecie")

ax2.plot(gdp_x,gdp_y)
ax2.set_xlabel("PKB na osobę")
ax2.set_ylabel("prawdopodobieństwo")
ax2.set_title("Poziom PKB na osobę w wybranych państwach na świecie")

plt.savefig('distr.pdf', format='pdf')

# %% [markdown]
# ## Miary

# %% [markdown]
# ### położenia

# %%
[np.mean(happiness),np.mean(gdp)] # średnia arytmetyczna
# Out:
# [5.475456508927939, 0.9303918053994943]

# %%
[statistics.harmonic_mean(happiness), statistics.harmonic_mean(gdp)] # średnia harmoniczna
# Out:
# [5.230075729883818, 0.5863798408943933]

# %%
[sp.stats.mstats.gmean(happiness),sp.stats.mstats.gmean(gdp)] # średnia geometryczna
# Out:
# [5.355272629738088, 0.8123785755984831]

# %%
[sp.stats.trim_mean(happiness, 0.1),sp.stats.trim_mean(gdp, 0.1)] # średnia ucinana 10%
# Out:
# [5.47725197357188, 0.9461849325150079]

# %%
[np.median(happiness),np.median(gdp)] # mediana
# Out:
# [5.488, 0.995538592]

# %%
qw_hap = []
qw_gdp = []

qw_hap.append(np.quantile(happiness, 0.25))
qw_hap.append(np.quantile(happiness, 0.5))
qw_hap.append(np.quantile(happiness, 0.75))

qw_gdp.append(np.quantile(gdp, 0.25))
qw_gdp.append(np.quantile(gdp, 0.5))
qw_gdp.append(np.quantile(gdp, 0.75))

print(qw_hap,qw_gdp) #kwartyle
# Out:
# [4.599999901, 5.488, 6.301] [0.6454459294999999, 0.995538592, 1.228785]

# %% [markdown]
# ### rozproszenia

# %%
[max(happiness) - min(happiness), max(gdp) - min(gdp)] # rozstęp
# Out:
# [5.24180007, 2.0807]

# %%
[qw_hap[2] - qw_hap[0],qw_gdp[2] - qw_gdp[0]] # IQR = Q3 - Q1
# Out:
# [1.7010000989999998, 0.5833390705000001]

# %%
[statistics.variance(happiness),statistics.variance(gdp)] # wariancja nieobciążona
# Out:
# [1.262955820839609, 0.14791564146534145]

# %%
[math.sqrt(statistics.variance(happiness)),math.sqrt(statistics.variance(gdp))] # DX nieobciążone
# Out:
# [1.123813072018478, 0.3845980258209101]

# %%
[math.sqrt(statistics.variance(happiness))/np.mean(happiness) * 100,math.sqrt(statistics.variance(gdp))/np.mean(gdp) * 100] # współczynnik zmienności
# Out:
# [20.524554805358388, 41.3372112253042]

# %% [markdown]
# ### spłaszczenia

# %%
[sp.stats.kurtosis(np.array(happiness), fisher=False, axis=0), sp.stats.kurtosis(np.array(gdp), fisher=False, axis=0)] #kurtoza
# Out:
# [2.2549699255949816, 2.31358780981397]

# %% [markdown]
# ### skośności

# %%
[sp.stats.skew(happiness, axis=None, bias=False), sp.stats.skew(gdp, axis=None, bias=False)] # skośność
# Out:
# [-0.014127691003638412, -0.3602304575155037]

# %% [markdown]
# # Analiza zależności liniowej pomiędzy zmienną zależną a zmienną niezależną

# %% [markdown]
# ## prezentacja danych (wykres rozproszenia) i określenie zależności

# %%
plt.figure(figsize = (10,5))
plt.scatter(gdp,happiness,s=7)
plt.xlabel("PKB na osobę")
plt.ylabel("poziom szczęścia")
plt.title("Wykres zależności poziomu szczęścia od PKB na osobę")

plt.savefig('plot1.pdf', format='pdf')

# %% [markdown]
# ## estymacja punktowa współczynników w klasycznym modelu regresji

# %% [markdown]
# Współczynniki $\beta_{0}$, $\beta_{1}$ estymujemy ze wzoru wyprowadzonego przy użyciu metody najmniejszych kwadratów
# $$
# \left\{ \begin{array}{ll}
# \beta_{1} = r\frac{S_{y}}{S_{x}}\\
# \beta_{0} = \bar{y} - r\beta_{1}\bar{x}
# \end{array} \right.,
# $$ gdzie
#
# $r = \frac{1}{n-1}\frac{\sum_{i=1}^{n}(x_i-\bar{x})(y_i-\bar{y})}{S_{x}S_{y}}$,
#
# $S_{x} = \sqrt{\frac{1}{n-1}\sum_{i=1}^{n}(x_{i}-\bar{x})^{2}}$,
#
# $S_{y} = \sqrt{\frac{1}{n-1}\sum_{i=1}^{n}(y_{i}-\bar{y})^{2}}$,
#
# $\bar{x} = \frac{1}{n}\sum_{i=1}^{n}x_{i}$,
#
# $\bar{y} = \frac{1}{n}\sum_{i=1}^{n}y_{i}$.

# %%
def mnk(dane_x, dane_y):

    n = len(dane_x)
    x_avg = np.mean(dane_x)
    sx = np.sqrt(sum([(i-x_avg)**2 for i in dane_x])/(n-1))

    y_avg = np.mean(dane_y)
    sy = np.sqrt(sum([(i-y_avg)**2 for i in dane_y])/(n-1))

    r = sum([(dane_x[i]-x_avg)*(dane_y[i]-y_avg) for i in range(n)])/(sx*sy*(n-1))

    a = r*sy/sx
    b = y_avg - a*x_avg

    return a, b

# %%
b1, b0 = mnk(np.array(gdp),np.array(happiness))
print(b1, b0)
# Out:
# 2.3163657214649653 3.320328823368648

# %%
plt.figure(figsize = (10,5))
plt.scatter(gdp,happiness,s=7)
plt.xlabel("PKB na osobę")
plt.ylabel("poziom szczęścia")
plt.title("Wykres zależności poziomu szczęścia od PKB na osobę")
x = np.linspace(min(gdp), max(gdp), 1000)
y = [b1*i + b0 for i in x]
plt.plot(x,y, color="r")

plt.savefig('plot2.pdf', format='pdf')

# %% [markdown]
# ## estymacja przedziałowa współczynników w klasycznym modelu regresji

# %% [markdown]
# zakładamy, że unormowane $\beta_{0}$, $\beta_{1}$ mają rozkład t-studenta z n-2 stopniami swobody, zatem przedziały ufności mają postać
# $$
# \left\{ \begin{array}{ll}
# P\left(\hat{\beta}_{0}-t_{n-2}(1-\frac{\alpha}{2})S\sqrt{\frac{1}{n}+\frac{\bar{x}^{2}}{\sum_{i=1}^{n}(x_i-\bar{x})^2}} < \beta_{0} < \hat{\beta}_{0}+t_{n-2}(1-\frac{\alpha}{2})S\sqrt{\frac{1}{n}+\frac{\bar{x}^{2}}{\sum_{i=1}^{n}(x_i-\bar{x})^2}}\right) = 1-\alpha\\
# P\left(\hat{\beta}_{1}-t_{n-2}(1-\frac{\alpha}{2})\frac{S}{\sqrt{\sum_{i=1}^{n}(x_i-\bar{x})^2}} < \beta_{1} < \hat{\beta}_{1}+t_{n-2}(1-\frac{\alpha}{2})\frac{S}{\sqrt{\sum_{i=1}^{n}(x_i-\bar{x})^2}}\right) = 1-\alpha
# \end{array} \right.,
# $$ gdzie
#
# $S = \sqrt{\frac{\sum_{i=1}^{n}(y_i - \hat{y}_i)^2}{n-2}}$.

# %%
def przedzialy_b1_b0(dane_x, dane_y, a):
    b1, b0 = mnk(dane_x, dane_y)
    n = len(dane_x)
    x_avg = np.mean(dane_x)
    y_avg = np.mean(dane_y)
    
    y_est = [b1*i+b0 for i in dane_x]
    S = np.sqrt(sum([(dane_y[i]-y_est[i])**2 for i in range(n)])/(n-2))
    t = scipy.stats.t.ppf(1 - a / 2, df=n - 2)
    C0 = S * np.sqrt(1 / n + x_avg ** 2 / sum([(i - x_avg) ** 2 for i in dane_x]))
    C1 = S / np.sqrt(sum([(i - x_avg) ** 2 for i in dane_x]))
    
    return (b1-t*C1, b1+t*C1), (b0-t*C0, b0+t*C1)

# %%
b1_prz, b0_prz = przedzialy_b1_b0(np.array(gdp),np.array(happiness), 0.05)
print(b1_prz, b0_prz)
# Out:
# (2.191886234291911, 2.4408452086380197) (3.195020723295253, 3.4448083105417022)

# %% [markdown]
# Zatem z 95% prawdopodobieństwem $\beta_{1} \in \left(2.1919, 2.4408\right)$, $\beta_{0} \in \left(3.1950, 3.4448\right)$

# %%
plt.figure(figsize = (10,5))
plt.scatter(gdp,happiness,s=7)
plt.xlabel("PKB na osobę")
plt.ylabel("poziom szczęścia")
plt.title("Wykres zależności poziomu szczęścia od PKB na osobę")
x = np.linspace(min(gdp), max(gdp), 1000)
y_est = [b1*i + b0 for i in x]
y_min = [b1_prz[0]*i + b0_prz[0] for i in x]
y_max = [b1_prz[1]*i + b0_prz[1] for i in x]
plt.plot(x,y_est, color="r")
plt.plot(x, y_min, color="g")
plt.plot(x, y_max, color="g")

# %% [markdown]
# ## ocena poziomu zależności (współczynnik korelacji Pearsona, SST, SSE, SSR)

# %% [markdown]
# #### współczynnik korelacji Pearsona

# %%
scipy.stats.pearsonr(gdp,happiness)
# Out:
# PearsonRResult(statistic=0.7927205206418927, pvalue=8.830806811292535e-172)

# %% [markdown]
# otrzymaliśmy $r \approx 0.7927$, co sugeruje dosyć silną pozytywną korelację liniową

# %% [markdown]
# #### SST
#
# $SST = \sum_{i=1}^{n}\left(y_i-\bar{y}\right)$

# %%
y_avg = np.mean(happiness)
SST = sum([(i - y_avg)**2 for i in happiness])
print(SST)
# Out:
# 997.7350984632913

# %% [markdown]
# #### SSE
#
# $SSE = \sum_{i=1}^{n}\left(y_i-\hat{y}_i\right)$

# %%
y_est = [b1*x+b0 for x in gdp]
SSE = sum([(happiness[i] - y_est[i])**2 for i in range(len(gdp))])
print(SSE)
# Out:
# 370.75255193264456

# %% [markdown]
# #### SSR
#
# $SSR = \sum_{i=1}^{n}\left(\hat{y}_i-\bar{y}\right)$

# %%
y_est = [b1*x+b0 for x in gdp]
y_avg = np.mean(happiness)
SSR = sum([(y_est[i] - y_avg)**2 for i in range(len(gdp))])
print(SSR)
# Out:
# 626.9825465306479

# %% [markdown]
# #### współczynnik determinancji
#
# $R^2 = \frac{SSR}{SST}$

# %%
R2 = SSR/SST
print(R2)
# Out:
# 0.6284058238467551

# %% [markdown]
# ## predykcja oraz przedziały ufności dla pewnej części danych

# %%
len(gdp)
# Out:
# 791

# %%
dfs = df.sort_values("gdp_per_capita")
happiness_s = dfs["happines_score"]
gdp_s = dfs["gdp_per_capita"]

# %% [markdown]
# Danych jest 791, więc zrobię estymację dla ostatnich 20

# %%
n_pred = 20

x_pocz = np.array(gdp_s)[:-n_pred]
y_pocz = np.array(happiness_s)[:-n_pred]
b1_pocz, b0_pocz = mnk(x_pocz, y_pocz)
y_pocz_est = [b1_pocz*i + b0_pocz for i in x_pocz]
n_pocz = len(x_pocz)
x_pocz_avg = np.mean(x_pocz)

x_pred = np.array(gdp_s)[-n_pred:]
y_pred_teo = np.array(happiness_s)[-n_pred:]
y_pred_est = [b1_pocz*i + b0_pocz for i in x_pred]

# %%
x1 = np.linspace(x_pocz[0], x_pocz[-1], 1000)
y_est1 = [b1_pocz*i + b0_pocz for i in x1]
x2 = np.linspace(x_pocz[-1], x_pred[-1], 100)
y_est2 = [b1_pocz*i + b0_pocz for i in x2]

# %%
a = 0.05
S = np.sqrt(sum([(x_pocz[i]-y_pocz_est[i])**2 for i in range(n_pocz)])/(n_pocz-2))
t = scipy.stats.t.ppf(1 - a / 2, df=n_pocz - 2)
suma = sum([(i - x_pocz_avg)**2 for i in x_pocz])
Cy0 = [t*S*np.sqrt(1/n_pocz + (i-x_pocz_avg)**2/suma) for i in x2]
y_pred_min = [b1_pocz*x2[i] + b0_pocz - Cy0[i] for i in range(100)]
y_pred_max = [b1_pocz*x2[i] + b0_pocz + Cy0[i] for i in range(100)]

# %%
plt.figure(figsize = (10,5))
plt.scatter(x_pocz,y_pocz,s=7)
plt.scatter(x_pred, y_pred_est, s=7, color="g")
plt.xlabel("PKB na osobę")
plt.ylabel("poziom szczęścia")
plt.title("Wykres zależności poziomu szczęścia od PKB na osobę")
plt.plot(x1,y_est1, color="r", alpha=0.5)
plt.plot(x2,y_est2, alpha=0.5, linestyle="dashed")
plt.plot(x2, y_pred_min, alpha=0.5, linestyle="dashed", color="b")
plt.plot(x2, y_pred_max, alpha=0.5, linestyle="dashed", color="b")

# %% [markdown]
# # Analiza residuów

# %% [markdown]
# ## sprawdzenie założeń: średnia równa zero, stała wariancja, niezależność residuów, rozkład normalny

# %%
residuals = [happiness[i]-(b1*gdp[i] + b0) for i in range(len(gdp))]

# %%
plt.figure(figsize = (10,5))
plt.scatter(gdp,residuals,s=7)
plt.axhline(0,color = "r")

plt.savefig('res.pdf', format='pdf')

# %%
np.mean(residuals)   # wartość oczekiwana  ≈ 0
# Out:
# 1.8302538863605616e-15

# %%
np.var(residuals) # widzimy na wykresie że jest mniej więcej stała
# Out:
# 0.46871371925745203

# %%
stat, p_value = scipy.stats.levene(random.sample(residuals,350),random.sample(residuals,350))
if p_value > 0.05:
    print("Wariancja jest raczej stała.")
else:
    print("Wariancja raczej nie jest stała.")
# Out:
# Wariancja jest raczej stała.

# %%
plt.figure(figsize = (10,5)) # sprawdzamy czy rozkład residuuów jest rozkładem normalnum
plt.hist(residuals, bins=20, density=True, facecolor = '#2ab0ff', edgecolor='#169acf', linewidth=0.5)
mu, std = np.mean(residuals), np.std(residuals)
x = np.linspace(mu - 3*std, mu + 3*std, 100)
plt.plot(x, scipy.stats.norm.pdf(x, mu, std), "r")

plt.savefig('res_hist.pdf', format='pdf')

# %%
stat, p = scipy.stats.normaltest(residuals)

if p > 0.05:
    print('Dane z rozkładu normalnego')
else:
    print('Dane nie pochodzą z rozkładu normalnego')
# Out:
# Dane nie pochodzą z rozkładu normalnego
